# %% [markdown]
# ![Sparks-Student-Foundation-The-Sparks-Foundation.png](attachment:Sparks-Student-Foundation-The-Sparks-Foundation.png)

# %% [markdown]
# ## A GRIPNOV2021 Task#2 submission by Supriya Raturi

# %% [markdown]
# ## Topic : Prediction using Unupervised ML

# %% [markdown]
# **Problem Statement:**
# From the *IRIS* dataset predict the optimal number of clusters and represent them visually.

# %%
#Import Libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
# Load the dataset
df1 = sns.load_dataset('iris')
df1.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Shape of the data
df1.shape
# Out:
# (150, 5)

# %%
# Informational summary
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %% [markdown]
# **Observation:**
# 1. All features are numeric types
# 2. None of the features contains null values.

# %%
# Descriptive summary
df1.describe().T
# Out:
#               count      mean       std  min  25%   50%  75%  max
# sepal_length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# sepal_width   150.0  3.057333  0.435866  2.0  2.8  3.00  3.3  4.4
# petal_length  150.0  3.758000  1.765298  1.0  1.6  4.35  5.1  6.9
# petal_width   150.0  1.199333  0.762238  0.1  0.3  1.30  1.8  2.5

# %%
df1['species'].value_counts()
# Out:
# setosa        50
# versicolor    50
# virginica     50
# Name: species, dtype: int64

# %% [markdown]
# **Inference:**
# 1. All the 3 species are equally distributed comprising of 50 records.

# %% [markdown]
# ## Exploratory data analysis

# %%
# Visualization using pairplot
sns.pairplot(df1, diag_kind='kde',hue='species');

# %%
# Scatter plot between sepal_length and sepal_width
sns.scatterplot(df1['sepal_length'],df1['sepal_width'],hue=df1['species']);

# %%
# Scatter plot between petal_length and petal_width
sns.scatterplot(df1['petal_length'],df1['petal_width'],hue=df1['species']);

# %% [markdown]
# **Inference:**
# 1. From the two scatterplot we can see that SETOSA can be easily identified from the 3 species as it has smaller petal width and petal length also smaller sepal length and greater sepal width.
# 2. Versicolor and Virgina are bit tricky to identify as they have similar sepal width and sepal length.

# %% [markdown]
# ## Model Building

# %%
#drop 'species' column
df2 = df1.drop(['species'],axis=1)
df2.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
sns.pairplot(df2, diag_kind='kde');

# %% [markdown]
# **Inference:**
# 1. From the pairplot we can see 2 peaks hence there will be atleast 2 cluster formation.

# %% [markdown]
# **Scaling the data**

# %%
from sklearn.preprocessing import StandardScaler

# %%
SS = StandardScaler()

data = pd.DataFrame(SS.fit_transform(df2),columns=df2.columns)
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0     -0.900681     1.019004     -1.340227    -1.315444
# 1     -1.143017    -0.131979     -1.340227    -1.315444
# 2     -1.385353     0.328414     -1.397064    -1.315444
# 3     -1.506521     0.098217     -1.283389    -1.315444
# 4     -1.021849     1.249201     -1.340227    -1.315444

# %%
# Finding optimal cluster size for KMeans
# Calculating MSE for various cluster sizes

n_clusters = range(1,10,1)
mse = []

for i in n_clusters:
    km1 = KMeans(n_clusters=i)
    km_model1 = km1.fit(data)
    error = km_model1.inertia_
    
    mse.append(error)
    
df_inertia = pd.DataFrame({'No of clusters':n_clusters,'Inertia':mse})
df_inertia
# Out:
#    No of clusters     Inertia
# 0               1  600.000000
# 1               2  222.361705
# 2               3  139.825435
# 3               4  114.354072
# 4               5   91.047670
# 5               6   81.534484
# 6               7   70.682269
# 7               8   62.473486
# 8               9   54.148123

# %%
# Plotting the df_inertia 
sns.set_style('darkgrid')
plt.figure(figsize=(12,5))
sns.lineplot(df_inertia['No of clusters'],df_inertia['Inertia'],marker='o')
plt.show()

# %% [markdown]
# **Inference:**
# 1. The optimum clusters is where the elbow occurs hence n = 3

# %%
kms = KMeans(n_clusters=3)

kms_model = kms.fit(data)
y_pred = kms_model.predict(data)

# %%
# Creatig a new colum called 'label' which stores the value of cluster label in 'df2' dataframe 
# df2 is copy of dataframe 'data'

df2 = data.copy('deep')

df2['label'] = y_pred
df2['label'].value_counts()
# Out:
# 2    53
# 1    50
# 0    47
# Name: label, dtype: int64

# %% [markdown]
# **Observation:**
# 1. We had 3 distinct species with 50 records each, although we are able to build 3 clusters but value counts of label grerated by the machine shows different values.
# 2. Label-1 is the only cluster which contains 50 records, same as original data.

# %% [markdown]
# **Lets see which label indicates which species using pairplot -**

# %%
# Pairplot of dataframe df2
sns.pairplot(df2, diag_kind='kde',hue='label',palette = 'bright');

# %%
# Pairplot of dataframe df1
sns.pairplot(df1, diag_kind='kde',hue='species');

# %% [markdown]
# **Observation:**
#
# By carefully studying the pairplot we can say,
# * Label 0 - Virginica
# * Label 1 - Setosa
# * Label 2 - Versicolor
#
# Hence we are able to identify SETOSA properly just as we thought.

# %% [markdown]
# **Plotting the clusters on first two features**

# %%
# Inverse tranforming the cluster centers
# This is done so that we can plot the cluster centers on the orginal data.
# kms_model.cluster_centers_ stores the scaled cluster value

x = SS.inverse_transform(kms_model.cluster_centers_)

# %%
# Scatter plot between sepal_length and sepal_width
sns.scatterplot(df1['sepal_length'],df1['sepal_width'],hue=df2['label'],palette = 'bright');
plt.scatter(x[:, 0], x[:,1], s = 50, c = 'black', label = 'Centroids')

plt.legend()

# %% [markdown]
# ## Thankyou..
